# %% [markdown]
# User will input (**3** ages). Find the **oldest** one.

# %%
a = int(input("Enter the first age: "))
b = int(input("Enter the second age: "))
c = int(input("Enter the third age: "))

max_age = a

if max_age < b:
    max_age = b

if max_age < c:
    max_age = c

print(max_age)
# Out:
# Enter the first age: 25
# Enter the second age: 50
# Enter the third age: 75
# 75
