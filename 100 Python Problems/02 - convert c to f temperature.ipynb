# %% [markdown]
# Write a program that converts **Celsius** values to **Fahrenheit**.

# %%
temp = float(input("Enter the temperature in Celsius: "))

fahrenheit = (temp * 1.8) + 32

print(fahrenheit)
# Out:
# Enter the temprature in celsius: 25
# 77.0
