# %% [markdown]
# Write a function that accepts a string and returns the number of upper case chars and lower case chars as a dictionary

# %%
a = input('Enter your string: ')
D = {}
upper_count = 0
lower_count = 0

for i in a:
    if(i.isupper()):
        upper_count = upper_count + 1
    elif(i.islower()):
        lower_count = lower_count + 1
D = {'Upper case:': upper_count, 'Lower_case': lower_count}
print(D)
# Out:
# Enter your string: My name is Saurabh Singh Dhami
# {'Upper case:': 4, 'Lower_case': 21}
