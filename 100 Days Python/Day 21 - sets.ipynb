# %% [markdown]
# # Sets

# %%
# 4 important rules about sets:

# 1. Sets do not allow duplicates
# 2. Sets have no indexing/slicing
# 3. Sets do not allow mutable data types
# 4. Set itself is a mutable data type

# %% [markdown]
# - 1. Create
# - 2. Access
# - 3. Edit
# - 4. Add
# - 5. Delete
# - 6. Operations
# - 7. Functions

# %% [markdown]
# ### Create

# %%
S1 = {}
S1
# Out:
# {}

# %%
type(S1)
# Out:
# dict

# %%
S1 = set()
S1
# Out:
# set()

# %%
type(S1)
# Out:
# set

# %%
S1 = {1,2,3,4,5}
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2 = {"Hello",4.5,True}
S2
# Out:
# {4.5, 'Hello', True}

# %%
S3 = {1,1,2,2,3,3}
S3
# Out:
# {1, 2, 3}

# %%
S4 = {[1,2,3],"Hello"}
S4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/699861372.py in <module>
# ----> 1 S4 = {[1,2,3],"Hello"}
#       2 S4
#
# TypeError: unhashable type: 'list'

# %%
S4 = {(1,2,3),"Hello"}
S4
# Out:
# {(1, 2, 3), 'Hello'}

# %%
# Sets have no indexing
# Hashing

# %%
S5 = {{1},{2}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/242894404.py in <module>
# ----> 1 S5 = {{1},{2}}
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# ### Access

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/1819249319.py in <module>
# ----> 1 S1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/387789777.py in <module>
# ----> 1 S1[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/3138535836.py in <module>
# ----> 1 S1[0:3]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Edit

# %%
S1[2] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/2261523821.py in <module>
# ----> 1 S1[2] = 100
#
# TypeError: 'set' object does not support item assignment

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
id(S1)
# Out:
# 2360860911200

# %%
L = list(S1)
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L[0] = 100
L
# Out:
# [100, 2, 3, 4, 5]

# %%
S1 = set(L)
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
id(S1)
# Out:
# 2360861818432

# %% [markdown]
# ### Add

# %%
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
S1.add(6)
S1
# Out:
# {2, 3, 4, 5, 6, 100}

# %%
id(S1)
# Out:
# 2360861818432

# %%
S1.add(7)
S1
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %%
id(S1)
# Out:
# 2360861818432

# %% [markdown]
# ### Delete

# %%
# del
# remove
# pop

# %%
S2
# Out:
# {4.5, 'Hello', True}

# %%
del S2
S2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/2217217462.py in <module>
#       1 del S2
# ----> 2 S2
#
# NameError: name 'S2' is not defined

# %%
del S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/2134711622.py in <module>
# ----> 1 del S1[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %%
S1.remove(100)
S1
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
S1.pop()
S1
# Out:
# {3, 4, 5, 6, 7}

# %%
S1.pop()
S1
# Out:
# {4, 5, 6, 7}

# %% [markdown]
# ### Operations

# %%
S1 = {1,2,3,4,5}
S2 = {3,4,5,6,7}

# %%
S1 + S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/1770448246.py in <module>
# ----> 1 S1 + S2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
S1 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20820/1009700113.py in <module>
# ----> 1 S1 * 3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
for i in S1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
1 in S1
# Out:
# True

# %% [markdown]
# ### Functions

# %%
len(S1)
# Out:
# 5

# %%
min(S1)
# Out:
# 1

# %%
max(S1)
# Out:
# 5

# %%
sorted(S1)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(S1,reverse = True)
# Out:
# [5, 4, 3, 2, 1]

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2
# Out:
# {3, 4, 5, 6, 7}

# %%
S1.union(S2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
S1.intersection(S2)
# Out:
# {3, 4, 5}

# %%
S1.difference(S2)
# Out:
# {1, 2}

# %%
S2.difference(S1)
# Out:
# {6, 7}

# %%
S1.symmetric_difference(S2)
# Out:
# {1, 2, 6, 7}

# %%
S1.isdisjoint(S2)
# Out:
# False

# %%
S1.issubset(S2)
# Out:
# False

# %%
S1.issuperset(S2)
# Out:
# False

# %%
S1.clear()
S1
# Out:
# set()
