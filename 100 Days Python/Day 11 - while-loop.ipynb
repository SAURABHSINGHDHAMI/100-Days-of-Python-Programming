# %%
# while
# for

# %%
# In C lang
while(condition){
    code
}

# %%
# In Python
while condition:
    code

# %%
number = int(input("Enter the number: "))

i = 1

while i<11:
    print(number * i)
    i+=1
# Out:
# Enter the number: 11
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110

# %%
number = int(input("Enter the number: "))

i = 1

while i<11:
    print(number,"*",i,"=",number * i)
    i+=1
# Out:
# Enter the number: 11
# 11 * 1 = 11
# 11 * 2 = 22
# 11 * 3 = 33
# 11 * 4 = 44
# 11 * 5 = 55
# 11 * 6 = 66
# 11 * 7 = 77
# 11 * 8 = 88
# 11 * 9 = 99
# 11 * 10 = 110
