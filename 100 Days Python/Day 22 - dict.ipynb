# %% [markdown]
# # Dictionary

# %%
{"Name":"Saurabh","Gender":"Male"}
# Out:
# {'Name': 'Saurabh', 'Gender': 'Male'}

# %%
# 4 important rules about dictionary:

# 1. Dictionary has no indexing
# 2. Dictionary is a mutable data type
# 3. Keys->immutable, Values->they can be mutable
# 4. Keys should be unique

# %%
# Mutable - Lists/Sets/Dictionary
# Immutable - Strings/tuples/int/float/Boolean/complex

# %% [markdown]
# - 1. Create
# - 2. Access
# - 3. Edit
# - 4. Add
# - 5. Delete
# - 6. Operations
# - 7. Functions

# %% [markdown]
# ### Create

# %%
D = {}
D
# Out:
# {}

# %%
D = {"Name":"Saurabh","Gender":"Male"}
D
# Out:
# {'Name': 'Saurabh', 'Gender': 'Male'}

# %%
D1 = {[1,2,3]:"Saurabh"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/231526580.py in <module>
# ----> 1 D1 = {[1,2,3]:"Saurabh"}
#
# TypeError: unhashable type: 'list'

# %%
D1 = {(1,2,3):"Saurabh"}
D1
# Out:
# {(1, 2, 3): 'Saurabh'}

# %%
D2 = {"Name":"Natty","Name":"Maru"}
D2
# Out:
# {'Name': 'Maru'}

# %%
D3 = {"Name":"Saurabh","College":"SGT","Marks":{"M1":99,"DS":97,"Eng":98}}
D3
# Out:
# {'Name': 'Saurabh', 'College': 'SGT', 'Marks': {'M1': 99, 'DS': 97, 'Eng': 98}}

# %% [markdown]
# ### Access

# %%
D
# Out:
# {'Name': 'Saurabh', 'Gender': 'Male'}

# %%
D[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/3858647015.py in <module>
# ----> 1 D[0]
#
# KeyError: 0

# %%
D["Name"]
# Out:
# 'Saurabh'

# %%
D.get("Name")
# Out:
# 'Saurabh'

# %%
D["Gender"]
# Out:
# 'Male'

# %%
D.get("Gender")
# .get() function only for 1D Dictionary not for 2D Dictionary
# Out:
# 'Male'

# %%
D3
# Out:
# {'Name': 'Saurabh', 'College': 'SGT', 'Marks': {'M1': 99, 'DS': 97, 'Eng': 98}}

# %%
D3["Marks"]["DS"]
# Out:
# 97

# %% [markdown]
# ### Edit

# %%
D
# Out:
# {'Name': 'Saurabh', 'Gender': 'Male'}

# %%
D["Name"] = "Kartik"
D
# Out:
# {'Name': 'Kartik', 'Gender': 'Male'}

# %%
D3["Marks"]["DS"] = 10
D3
# Out:
# {'Name': 'Saurabh', 'College': 'SGT', 'Marks': {'M1': 99, 'DS': 10, 'Eng': 98}}

# %% [markdown]
# ### Add

# %%
D
# Out:
# {'Name': 'Kartik', 'Gender': 'Male'}

# %%
D["Age"] = 22
D
# Out:
# {'Name': 'Kartik', 'Gender': 'Male', 'Age': 22}

# %%
D3["Marks"]["M2"] = 95
D3
# Out:
# {'Name': 'Saurabh', 'College': 'SGT', 'Marks': {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}}

# %% [markdown]
# ### Delete

# %%
D5 = {}
D5
# Out:
# {}

# %%
del D5
D5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/1783440616.py in <module>
#       1 del D5
# ----> 2 D5
#
# NameError: name 'D5' is not defined

# %%
D
# Out:
# {'Name': 'Kartik', 'Gender': 'Male', 'Age': 22}

# %%
del D["Gender"]
D
# Out:
# {'Name': 'Kartik', 'Age': 22}

# %%
D.clear()
D
# Out:
# {}

# %% [markdown]
# ### Operations

# %%
D1
# Out:
# {(1, 2, 3): 'Saurabh'}

# %%
D2
# Out:
# {'Name': 'Maru'}

# %%
D1 + D2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/3579322690.py in <module>
# ----> 1 D1 + D2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D1 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2812/4203859800.py in <module>
# ----> 1 D1 * 3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
D3
# Out:
# {'Name': 'Saurabh', 'College': 'SGT', 'Marks': {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}}

# %%
for i in D3:
    print(i)
# Out:
# Name
# College
# Marks

# %%
for i in D3:
    print(i,D3[i])
# Out:
# Name Saurabh
# College SGT
# Marks {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}

# %%
"Saurabh" in  D3
# Out:
# False

# %%
"Name" in  D3
# Out:
# True

# %% [markdown]
# ### Functions

# %%
len(D3)
# Out:
# 3

# %%
min(D3)
# Out:
# 'College'

# %%
max(D3)
# Out:
# 'Name'

# %%
sorted(D3)
# Out:
# ['College', 'Marks', 'Name']

# %%
sorted(D3,reverse = True)
# Out:
# ['Name', 'Marks', 'College']

# %%
D3.keys()
# Out:
# dict_keys(['Name', 'College', 'Marks'])

# %%
D3.values()
# Out:
# dict_values(['Saurabh', 'SGT', {'M1': 99, 'DS': 10, 'Eng': 98, 'M2': 95}])
