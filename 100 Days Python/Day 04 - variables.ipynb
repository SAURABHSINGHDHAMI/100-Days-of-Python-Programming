# %%
# C lang
# int a = 5

# %%
name = 'Saurabh'

# %%
print(name)
# Out:
# Saurabh

# %%
name = 'Hello World'
print(name)
# Out:
# Hello World

# %%
# no variable declaration

# %%
# Dynamic Typing --> PHP
# Static Typing

# %%
print(name)
# Out:
# Hello World

# %%
name = 4
print(name)
# Out:
# 4

# %%
name = True
print(name)
# Out:
# True

# %%
# Dynamic Binding

# %%
# Static Binding

# %%
# special syntax
a = 5; b = 6; c = 7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a, b, c = 5, 6, 7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a = b = c = 6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
