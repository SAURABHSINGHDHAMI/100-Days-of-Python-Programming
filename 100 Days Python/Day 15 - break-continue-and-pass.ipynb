# %%
for i in range(1,11):
    if i == 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,11):
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
for i in range(1,11):
    if i ==5:
        continue
    print(i)
    print("Hello")
# Out:
# 1
# Hello
# 2
# Hello
# 3
# Hello
# 4
# Hello
# 6
# Hello
# 7
# Hello
# 8
# Hello
# 9
# Hello
# 10
# Hello

# %%
for i in range(1,11):
    pass
